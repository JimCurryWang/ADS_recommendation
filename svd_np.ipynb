# %%
import numpy as np
import pandas as pd
from tqdm.auto import tqdm
import time
import random

# %%
def load_data(filename):
    data_list = []
    with open(filename, 'r') as data:
        for line in tqdm(data):
            user_id, item_id, rating, timestamp = line.split('\t')
            data_list.append([int(user_id), int(item_id), int(rating)])
            
    print('data loading complete')
    return data_list

# %%
train_data = load_data('ml-100k/u1.base')
test_data = load_data('ml-100k/u1.test')
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# data loading complete
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# data loading complete

# %% [markdown]
# # SVD

# %%
class SVD():

    # Initializing the user-movie rating matrix, no. of latent features
    def __init__(self, ratings, num_users, num_items, dim):
        self.ratings = ratings
        self.num_users, self.num_items = num_users, num_items
        self.dim = dim
        self.mu = np.mean([i[2] for i in ratings])
        
        self.P = np.random.normal(scale=1./self.dim, size=(self.num_users, self.dim))
        self.Q = np.random.normal(scale=1./self.dim, size=(self.num_items, self.dim))

        # Initializing the bias terms
        self.b_u = np.zeros(self.num_users)
        self.b_i = np.zeros(self.num_items)
        
    # Initializing user-feature and movie-feature matrix 
    def train(self,  lr_rate, weight_decay, thresold, epoches):
        self.lr_rate = lr_rate
        self.weight_decay = weight_decay
        
        #delta = np.inf
        #idx = 1
        #past_loss = np.inf
        print('Begin training')
        start = time.process_time()
        #while delta > thresold :
        #curren_loss = np.inf
        #while curren_loss <= past_loss:
        for i in tqdm(range(epoches)):
            #past_loss = curren_loss
            random.shuffle(self.ratings)
            for user, item, rating in self.ratings:
                
                predict = self.get_rating(user, item)
                delta = max(self.sgd(user, item, rating, predict))
            curren_loss = self.rmse()
            #print('epoch : {0}  loss = '.format(idx), curren_loss)
            print('epoch : {0} / {1} loss = '.format(i+1, epoches), curren_loss)
            #idx+=1
            self.evaluate(test_data)
            #print(delta)
        print('Training complete \n\nTime past : %.2f seconds'%(time.process_time()-start))
        
    def evaluate(self, test_data):
        predicted = self.full_matrix()
        error = 0
        for i, j, rating in test_data:
             error += pow(rating - predicted[i-1, j-1], 2)
           
        print('RMSE of testing data : %.4f'%np.sqrt(error/len(test_data))) 
    # Computing total mean squared error
    def rmse(self):
        
        predicted = self.full_matrix()
        error = 0
        for i, j, rating in self.ratings:
             error += pow(rating - predicted[i-1, j-1], 2)
           
        return np.sqrt(error/len(self.ratings))

    # Stochastic gradient descent to get optimized P and Q matrix
    def sgd(self, i, j, true, predict):
        
       
        e = (true - predict)

        self.b_u[i-1] += self.lr_rate * (e - self.weight_decay * self.b_u[i-1])
        self.b_i[j-1] += self.lr_rate * (e - self.weight_decay * self.b_i[j-1])

        tmp = e * self.P[i-1, :] - self.weight_decay * self.Q[j-1,:]
        
        self.P[i-1, :] += self.lr_rate * (e * self.Q[j-1, :] - self.weight_decay * self.P[i-1,:])
        
        self.Q[j-1, :] += self.lr_rate * (tmp)
   
        return [np.abs(self.lr_rate * (e - self.weight_decay * self.b_u[i-1])),
                np.abs(self.lr_rate * (e - self.weight_decay * self.b_i[j-1])),
                max(np.abs(self.lr_rate * (e * self.Q[j-1, :] - self.weight_decay * self.P[i-1,:]))),
                max(np.abs(self.lr_rate * (tmp)))
               ]
    # Ratings for user i and moive j
    def get_rating(self, i, j):
        prediction = self.mu + self.b_u[i-1] + self.b_i[j-1] + self.P[i-1, :].dot(self.Q[j-1, :].T)
        return prediction

    # Full user-movie rating matrix
    def full_matrix(self):
        return self.mu + self.b_u[:,np.newaxis] + self.b_i[np.newaxis:,] + self.P.dot(self.Q.T)

# %%
len_u = 943
len_v = 1682
#batch_size = 10
lr_rate = 0.005
weight_decay= 0.1#0.05
thresold = 1e-5
epoches = 100
dim = 100
######################################
model_svd = SVD(ratings=train_data, num_users=len_u, num_items=len_v, dim=dim)
model_svd.train(lr_rate=lr_rate, weight_decay=weight_decay, thresold=thresold, epoches=epoches)
model_svd.evaluate(test_data)
# Out:
# Begin training
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# epoch : 1 / 100 loss =  0.9951667017590311
# RMSE of testing data : 1.0318
# epoch : 2 / 100 loss =  0.9643995710763887
# RMSE of testing data : 1.0011
# epoch : 3 / 100 loss =  0.9498655690268534
# RMSE of testing data : 0.9874
# epoch : 4 / 100 loss =  0.9415426441182875
# RMSE of testing data : 0.9799
# epoch : 5 / 100 loss =  0.9358128028601135
# RMSE of testing data : 0.9748
# epoch : 6 / 100 loss =  0.931730829322305
# RMSE of testing data : 0.9714
# epoch : 7 / 100 loss =  0.9286188223536308
# RMSE of testing data : 0.9687
# epoch : 8 / 100 loss =  0.9262024579565997
# RMSE of testing data : 0.9664
# epoch : 9 / 100 loss =  0.9242999899070653
# RMSE of testing data : 0.9649
# epoch : 10 / 100 loss =  0.9228169965141758
# RMSE of testing data : 0.9635
# epoch : 11 / 100 loss =  0.9214873319885876
# RMSE of testing data : 0.9625
# epoch : 12 / 100 loss =  0.9205405410966926
# RMSE of testing data : 0.9614
# epoch : 13 / 100 loss =  0.919497478125933
# RMSE of testing data : 0.9606
# epoch : 14 / 100 loss =  0.918738058097417
# RMSE of testing data : 0.9600
# epoch : 15 / 100 loss =  0.9181956857024229
# RMSE of testing data : 0.9599
# epoch : 16 / 100 loss =  0.917535136550621
# RMSE of testing data : 0.9591
# epoch : 17 / 100 loss =  0.9169788541343247
# RMSE of testing data : 0.9588
# epoch : 18 / 100 loss =  0.916483104370963
# RMSE of testing data : 0.9583
# epoch : 19 / 100 loss =  0.9160060057013634
# RMSE of testing data : 0.9580
# epoch : 20 / 100 loss =  0.9156643911423955
# RMSE of testing data : 0.9579
# epoch : 21 / 100 loss =  0.9152793346753225
# RMSE of testing data : 0.9577
# epoch : 22 / 100 loss =  0.9149537068292617
# RMSE of testing data : 0.9574
# epoch : 23 / 100 loss =  0.9146300504398772
# RMSE of testing data : 0.9571
# epoch : 24 / 100 loss =  0.9142993760273284
# RMSE of testing data : 0.9570
# epoch : 25 / 100 loss =  0.9138215271322457
# RMSE of testing data : 0.9565
# epoch : 26 / 100 loss =  0.9135523035227874
# RMSE of testing data : 0.9563
# epoch : 27 / 100 loss =  0.9132272570624556
# RMSE of testing data : 0.9562
# epoch : 28 / 100 loss =  0.9128789237872489
# RMSE of testing data : 0.9560
# epoch : 29 / 100 loss =  0.9125667646573228
# RMSE of testing data : 0.9559
# epoch : 30 / 100 loss =  0.9121451640676345
# RMSE of testing data : 0.9559
# epoch : 31 / 100 loss =  0.9116471837465515
# RMSE of testing data : 0.9554
# epoch : 32 / 100 loss =  0.9113609106626404
# RMSE of testing data : 0.9551
# epoch : 33 / 100 loss =  0.9110167494051231
# RMSE of testing data : 0.9552
# epoch : 34 / 100 loss =  0.9103609039975702
# RMSE of testing data : 0.9547
# epoch : 35 / 100 loss =  0.9097884108178342
# RMSE of testing data : 0.9546
# epoch : 36 / 100 loss =  0.9092789819746242
# RMSE of testing data : 0.9542
# epoch : 37 / 100 loss =  0.9085043463112397
# RMSE of testing data : 0.9538
# epoch : 38 / 100 loss =  0.9076702013430779
# RMSE of testing data : 0.9530
# epoch : 39 / 100 loss =  0.9068075596157924
# RMSE of testing data : 0.9527
# epoch : 40 / 100 loss =  0.9059460608716169
# RMSE of testing data : 0.9522
# epoch : 41 / 100 loss =  0.9048414014084848
# RMSE of testing data : 0.9516
# epoch : 42 / 100 loss =  0.9037511745633666
# RMSE of testing data : 0.9508
# epoch : 43 / 100 loss =  0.9023991321390793
# RMSE of testing data : 0.9500
# epoch : 44 / 100 loss =  0.9011198681561771
# RMSE of testing data : 0.9493
# epoch : 45 / 100 loss =  0.8997222113922868
# RMSE of testing data : 0.9487
# epoch : 46 / 100 loss =  0.898132565466883
# RMSE of testing data : 0.9477
# epoch : 47 / 100 loss =  0.8966038869944168
# RMSE of testing data : 0.9468
# epoch : 48 / 100 loss =  0.8950407794036852
# RMSE of testing data : 0.9460
# epoch : 49 / 100 loss =  0.8933279555673926
# RMSE of testing data : 0.9450
# epoch : 50 / 100 loss =  0.8918631723579824
# RMSE of testing data : 0.9442
# epoch : 51 / 100 loss =  0.8901242074274436
# RMSE of testing data : 0.9433
# epoch : 52 / 100 loss =  0.8884577255600369
# RMSE of testing data : 0.9425
# epoch : 53 / 100 loss =  0.8867641916806652
# RMSE of testing data : 0.9416
# epoch : 54 / 100 loss =  0.8852439820328559
# RMSE of testing data : 0.9408
# epoch : 55 / 100 loss =  0.8835705899966172
# RMSE of testing data : 0.9396
# epoch : 56 / 100 loss =  0.8818919450632646
# RMSE of testing data : 0.9387
# epoch : 57 / 100 loss =  0.8804154392486215
# RMSE of testing data : 0.9382
# epoch : 58 / 100 loss =  0.8786873219747113
# RMSE of testing data : 0.9375
# epoch : 59 / 100 loss =  0.8772423975398418
# RMSE of testing data : 0.9371
# epoch : 60 / 100 loss =  0.8756524470798416
# RMSE of testing data : 0.9364
# epoch : 61 / 100 loss =  0.8740703895711054
# RMSE of testing data : 0.9356
# epoch : 62 / 100 loss =  0.8723459102640737
# RMSE of testing data : 0.9348
# epoch : 63 / 100 loss =  0.8706795748561315
# RMSE of testing data : 0.9342
# epoch : 64 / 100 loss =  0.8691061120359644
# RMSE of testing data : 0.9337
# epoch : 65 / 100 loss =  0.8675038601148729
# RMSE of testing data : 0.9333
# epoch : 66 / 100 loss =  0.8657060352255196
# RMSE of testing data : 0.9329
# epoch : 67 / 100 loss =  0.8639014622743922
# RMSE of testing data : 0.9323
# epoch : 68 / 100 loss =  0.8621940074133133
# RMSE of testing data : 0.9318
# epoch : 69 / 100 loss =  0.8603422195880843
# RMSE of testing data : 0.9310
# epoch : 70 / 100 loss =  0.8585036952982972
# RMSE of testing data : 0.9305
# epoch : 71 / 100 loss =  0.8566450390410877
# RMSE of testing data : 0.9301
# epoch : 72 / 100 loss =  0.8547236293308157
# RMSE of testing data : 0.9295
# epoch : 73 / 100 loss =  0.8528207829584136
# RMSE of testing data : 0.9294
# epoch : 74 / 100 loss =  0.8506783038977015
# RMSE of testing data : 0.9286
# epoch : 75 / 100 loss =  0.8485411947565199
# RMSE of testing data : 0.9281
# epoch : 76 / 100 loss =  0.8465269844507812
# RMSE of testing data : 0.9278
# epoch : 77 / 100 loss =  0.8443436683402563
# RMSE of testing data : 0.9271
# epoch : 78 / 100 loss =  0.8422419469433912
# RMSE of testing data : 0.9269
# epoch : 79 / 100 loss =  0.8400133113090686
# RMSE of testing data : 0.9263
# epoch : 80 / 100 loss =  0.8378064875374363
# RMSE of testing data : 0.9260
# epoch : 81 / 100 loss =  0.8356111893254117
# RMSE of testing data : 0.9256
# epoch : 82 / 100 loss =  0.8333412994204427
# RMSE of testing data : 0.9252
# epoch : 83 / 100 loss =  0.830964377287312
# RMSE of testing data : 0.9246
# epoch : 84 / 100 loss =  0.8286865652898656
# RMSE of testing data : 0.9242
# epoch : 85 / 100 loss =  0.8263686256434314
# RMSE of testing data : 0.9239
# epoch : 86 / 100 loss =  0.8240048467530048
# RMSE of testing data : 0.9234
# epoch : 87 / 100 loss =  0.8216848309608337
# RMSE of testing data : 0.9229
# epoch : 88 / 100 loss =  0.8193492564133265
# RMSE of testing data : 0.9229
# epoch : 89 / 100 loss =  0.8169943984299907
# RMSE of testing data : 0.9225
# epoch : 90 / 100 loss =  0.8145610123525483
# RMSE of testing data : 0.9220
# epoch : 91 / 100 loss =  0.8122266989488868
# RMSE of testing data : 0.9219
# epoch : 92 / 100 loss =  0.8098529574113216
# RMSE of testing data : 0.9217
# epoch : 93 / 100 loss =  0.8075010766284147
# RMSE of testing data : 0.9214
# epoch : 94 / 100 loss =  0.8050758240458769
# RMSE of testing data : 0.9211
# epoch : 95 / 100 loss =  0.8026590659118293
# RMSE of testing data : 0.9207
# epoch : 96 / 100 loss =  0.8003634216206437
# RMSE of testing data : 0.9207
# epoch : 97 / 100 loss =  0.7980442795873274
# RMSE of testing data : 0.9205
# epoch : 98 / 100 loss =  0.795788488871103
# RMSE of testing data : 0.9203
# epoch : 99 / 100 loss =  0.7933547156595189
# RMSE of testing data : 0.9199
# epoch : 100 / 100 loss =  0.7910434488577217
# RMSE of testing data : 0.9198
#
# Training complete
#
# Time past : 497.36 seconds
# RMSE of testing data : 0.9198

# %%
pre = model_svd.full_matrix()
for i, j, rating in train_data[:20]:
    print('real :', rating, 'predict : %.2f'%pre[i-1, j-1])
# Out:
# real : 3 predict : 3.16
# real : 4 predict : 4.73
# real : 2 predict : 3.30
# real : 3 predict : 3.42
# real : 3 predict : 2.93
# real : 3 predict : 4.25
# real : 2 predict : 2.83
# real : 5 predict : 3.67
# real : 5 predict : 4.36
# real : 1 predict : 2.69
# real : 4 predict : 3.85
# real : 4 predict : 2.70
# real : 5 predict : 4.39
# real : 5 predict : 4.40
# real : 1 predict : 0.92
# real : 4 predict : 3.73
# real : 5 predict : 3.70
# real : 1 predict : 2.70
# real : 3 predict : 3.76
# real : 4 predict : 3.98

# %%
for i, j, rating in test_data[:20]:
    print('real :', rating, 'predict : %.2f'%pre[i-1, j-1])
# Out:
# real : 5 predict : 3.70
# real : 3 predict : 3.98
# real : 5 predict : 4.55
# real : 5 predict : 4.03
# real : 3 predict : 3.25
# real : 4 predict : 3.79
# real : 4 predict : 4.31
# real : 3 predict : 3.63
# real : 2 predict : 3.03
# real : 3 predict : 3.63
# real : 4 predict : 3.61
# real : 2 predict : 2.47
# real : 4 predict : 3.39
# real : 5 predict : 3.16
# real : 4 predict : 3.81
# real : 3 predict : 3.44
# real : 4 predict : 3.43
# real : 3 predict : 3.01
# real : 3 predict : 3.24
# real : 4 predict : 4.41
